# %%
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import cvxpy as cp

from LibMTL._record import _PerformanceMeter
from LibMTL.utils import count_parameters, set_param
import LibMTL.weighting as weighting_method
import LibMTL.architecture as architecture_method
#import wandb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 from LibMTL._record import _PerformanceMeter
#       7 from LibMTL.utils import count_parameters, set_param
# ----> 8 import LibMTL.weighting as weighting_method
#       9 import LibMTL.architecture as architecture_method
#      10 #import wandb
#
# File /store/home/tibia/Projet_Hemorragie/LibMTL/LibMTL/LibMTL/__init__.py:4
#       2 from . import model
#       3 from . import weighting
# ----> 4 from .trainer import Trainer
#       5 from . import config
#       6 from . import loss
#
# File /store/home/tibia/Projet_Hemorragie/LibMTL/LibMTL/LibMTL/trainer.py:11
#       9 import LibMTL.weighting as weighting_method
#      10 import LibMTL.architecture as architecture_method
# ---> 11 import wandb
#      13 class Trainer(nn.Module):
#      14     r'''A Multi-Task Learning Trainer.
#      15
#      16     This is a unified and extensible training framework for multi-task learning.
#    (...)
#      78
#      79     '''
#
# ModuleNotFoundError: No module named 'wandb'
